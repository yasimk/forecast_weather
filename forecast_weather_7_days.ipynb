# %%
import csv
import pandas as pd
import csv
weather_api_url = 'http://api.openweathermap.org/data/2.5/forecast?APPID=242cc8f680efee3b2272be01b63227f7&zip='
zip_codes = ['75063', '10010', '05401', '99501', '14240', '94088', '69361']
data_list = []
city_list = []
for zip_in in zip_codes:
    weather_url = weather_api_url + zip_in
    print('\nWeather for zip code: ',zip_in, 'weather_url', weather_url)
    json_returns = requests.get(weather_url).json()
    #print(json_returns)
    for dictionary in json_returns:
        #print('Different dictionaries are: ', dictionary)
        if (dictionary == 'city'):
            city = json_returns['city']['name']
            lat_coord = json_returns['city']['coord']['lat']
            long_coord = json_returns['city']['coord']['lon']
            country = json_returns['city']['country']
            time_zone = json_returns['city']['timezone']
            print('City Details: ',city, zip_in, lat_coord, long_coord, country, time_zone)
            city_list.append([city, zip_in, lat_coord, long_coord, country, time_zone])
        if (dictionary == 'list'):
            for list_data in json_returns['list']:
                weather_forecast_date =  list_data['dt_txt']
                weather_forecast_temp =  list_data['main']['temp']
                weather_forecast_temp_min = list_data['main']['temp_min']
                weather_forecast_temp_max = list_data['main']['temp_max']

                weather_forecast_temp_far =  np.ceil((weather_forecast_temp - 273.15) * 1.8 + 32)
                weather_forecast_temp_min_far =  np.ceil((weather_forecast_temp_min - 273.15) * 1.8 + 32)
                weather_forecast_temp_max_far =  np.ceil((weather_forecast_temp_max - 273.15) * 1.8 + 32)

                weather_forecast_pressure = list_data['main']['pressure']
                weather_forecast_humidity = list_data['main']['humidity']
                weather_forecast_mini_desc = list_data['weather'][0]['main']
                weather_forecast_detl_desc = list_data['weather'][0]['description']
                weather_forecast_clouds = list_data['clouds']['all']
                weather_forecast_wind_speed = list_data['wind']['speed']
                for dictionary in list_data:
                    #print('Dictionaries inside List Data are: ', dictionary)
                    if (dictionary == 'rain'):
                         for dictionary in list_data['rain']:
                            weather_forecast_rain = list_data['rain']['3h']
                data_list.append([zip_in, weather_forecast_date, weather_forecast_temp_far, weather_forecast_pressure, weather_forecast_humidity,  weather_forecast_clouds, weather_forecast_wind_speed, weather_forecast_rain, weather_forecast_mini_desc, weather_forecast_detl_desc])
city_header = ['City', 'ZIP', 'Lat_Coord', 'Long_Coord', 'Country', 'Time_zone']
city_df = pd.DataFrame(data= city_list, columns=city_header)
#print(city_df)
data_header = ['ZIP', 'weather_forecast_date', 'weather_forecast_temp_far', 'weather_forecast_pressure', 'weather_forecast_humidity',  'weather_forecast_clouds', 'weather_forecast_wind_speed', 'weather_forecast_rain', 'weather_forecast_mini_desc', 'weather_forecast_detl_desc']
data_df = pd.DataFrame(data= data_list, columns=data_header)
#print(data_df)
weather_df = pd.merge(city_df, data_df, on='ZIP', how = 'left')
#print(weather_df)
weather_df.to_csv("weather_forecast_data.csv", sep=',', encoding='utf-8')
# Out:
# Weather for zip code:  75063 weather_url http://api.openweathermap.org/data/2.5/forecast?APPID=242cc8f680efee3b2272be01b63227f7&zip=75063
# City Details:  Lewisville 75063 32.9601 -96.9767 US -18000
#
# Weather for zip code:  10010 weather_url http://api.openweathermap.org/data/2.5/forecast?APPID=242cc8f680efee3b2272be01b63227f7&zip=10010
# City Details:  New York 10010 40.7306 -73.9867 US -14400
#
# Weather for zip code:  05401 weather_url http://api.openweathermap.org/data/2.5/forecast?APPID=242cc8f680efee3b2272be01b63227f7&zip=05401
# City Details:  Burlington 05401 44.4724 -73.2115 US -14400
#
# Weather for zip code:  99501 weather_url http://api.openweathermap.org/data/2.5/forecast?APPID=242cc8f680efee3b2272be01b63227f7&zip=99501
# City Details:  Anchorage 99501 61.2163 -149.8949 US -28800
#
# Weather for zip code:  14240 weather_url http://api.openweathermap.org/data/2.5/forecast?APPID=242cc8f680efee3b2272be01b63227f7&zip=14240
# City Details:  Buffalo 14240 42.7623 -78.8793 US -14400
#
# Weather for zip code:  94088 weather_url http://api.openweathermap.org/data/2.5/forecast?APPID=242cc8f680efee3b2272be01b63227f7&zip=94088
# City Details:  Sunnyvale 94088 37.3688 -122.0364 US -25200
#
# Weather for zip code:  69361 weather_url http://api.openweathermap.org/data/2.5/forecast?APPID=242cc8f680efee3b2272be01b63227f7&zip=69361
# City Details:  Scottsbluff 69361 41.8666 -103.6672 US -21600

# %%
weather_df
# Out:
#             City    ZIP  Lat_Coord  Long_Coord Country  Time_zone  \
# 0     Lewisville  75063    32.9601    -96.9767      US     -18000
# 1     Lewisville  75063    32.9601    -96.9767      US     -18000
# 2     Lewisville  75063    32.9601    -96.9767      US     -18000
# 3     Lewisville  75063    32.9601    -96.9767      US     -18000
# 4     Lewisville  75063    32.9601    -96.9767      US     -18000
# 5     Lewisville  75063    32.9601    -96.9767      US     -18000
# 6     Lewisville  75063    32.9601    -96.9767      US     -18000
# 7     Lewisville  75063    32.9601    -96.9767      US     -18000
# 8     Lewisville  75063    32.9601    -96.9767      US     -18000
# 9     Lewisville  75063    32.9601    -96.9767      US     -18000
# 10    Lewisville  75063    32.9601    -96.9767      US     -18000
# 11    Lewisville  75063    32.9601    -96.9767      US     -18000
# 12    Lewisville  75063    32.9601    -96.9767      US     -18000
# 13    Lewisville  75063    32.9601    -96.9767      US     -18000
# 14    Lewisville  75063    32.9601    -96.9767      US     -18000
# 15    Lewisville  75063    32.9601    -96.9767      US     -18000
# 16    Lewisville  75063    32.9601    -96.9767      US     -18000
# 17    Lewisville  75063    32.9601    -96.9767      US     -18000
# 18    Lewisville  75063    32.9601    -96.9767      US     -18000
# 19    Lewisville  75063    32.9601    -96.9767      US     -18000
# 20    Lewisville  75063    32.9601    -96.9767      US     -18000
# 21    Lewisville  75063    32.9601    -96.9767      US     -18000
# 22    Lewisville  75063    32.9601    -96.9767      US     -18000
# 23    Lewisville  75063    32.9601    -96.9767      US     -18000
# 24                     1007.77                         85
# 25                     1008.76                         81
# 26                     1007.37                         56
# 27                     1004.41                         48
# 28                     1003.50                         55
# 29                     1003.76                         66
# ..                         ...                        ...
# 250                    1010.52                         30
# 251                    1009.68                         25
# 252                    1010.02                         29
# 253                    1012.25                         58
# 254                    1012.95                         72
# 255                    1012.75                         73
# 256                    1013.10                         75
# 257                    1012.73                         49
# 258                    1011.60                         39
# 259                    1009.42                         38
# 260                    1008.14                         41
# 261                    1010.46                         60
# 262                    1011.43                         74
# 263                    1010.15                         80
# 264                    1009.95                         78
# 265                    1009.44                         49
# 266                    1008.34                         39
# 267                    1006.56                         38
# 268                    1005.98                         43
# 269                    1006.77                         62
# 270                    1006.61                         74
# 271                    1005.47                         85
# 272                    1005.00                         87
# 273                    1002.93                         59
# 274                    1000.68                         37
# 275                     998.33                         24
# 276                     997.89                         21
# 277                    1000.28                         43
# 278                    1002.11                         43
# 279                    1001.83                         57
#
#      weather_forecast_clouds  weather_forecast_wind_speed  \
# 0                         93                         1.94
# 1                        100                         3.28
# 2                        100                         3.17
# 3                         99                         4.03
# 4                         98                         3.85
# 5                         78                         4.97
# 6                         55                         3.96
# 7                          0                         2.81
# 8                         24                         2.59
# 9                        100                         3.40
# 10                       100                         5.26
# 11                        95                         5.58
# 12                        94                         5.23
# 13                        96                         3.84
# 14                        84                         5.01
# 15                        86                         5.11
# 16                        92                         3.05
# 17                       100                         3.67
# 18                       100                         5.59
# 19                        97                         2.79
# 20                        98                         4.57
# 21                       100                         5.44
# 22                        92                         6.49
# 23                        31                         4.82
# 24                        61                         3.27
# 25                       100                         3.14
# 26                        71                         3.51
# 27                        21                         4.48
# 28                        10                         6.04
# 29                        33                         6.04
# ..                       ...                          ...
# 250                       78                         4.92
# 251                        0                         2.96
# 252                       18                         2.80
# 253                      100                         2.94
# 254                      100                         1.54
# 255                       80                         1.42
# 256                       88                         0.75
# 257                       90                         2.21
# 258                       79                         5.75
# 259                       97                         5.34
# 260                       92                         6.08
# 261                      100                         5.78
# 262                      100                         4.67
# 263                      100                         2.18
# 264                       93                         2.95
# 265                      100                         4.46
# 266                      100                         6.63
# 267                       62                         5.83
# 268                       55                         5.76
# 269                       12                         4.30
# 270                       44                         3.34
# 271                       77                         2.61
# 272                       85                         3.05
# 273                       93                         4.35
# 274                       70                         3.27
# 275                        4                         0.63
# 276                        8                         3.03
# 277                       80                         5.89
# 278                       89                         6.92
# 279                      100                         3.65
#
#      weather_forecast_rain weather_forecast_mini_desc  \
# 0                    0.126                       Rain
# 1                    0.062                       Rain
# 2                    0.376                       Rain
# 3                    0.376                     Clouds
# 4                    0.376                     Clouds
# 5                    0.376                     Clouds
# 6                    0.376                     Clouds
# 7                    0.312                       Rain
# 8                    0.312                     Clouds
# 9                    0.312                     Clouds
# 10                   0.312                     Clouds
# 11                   0.312                     Clouds
# 12                   0.312                     Clouds
# 13                   0.312                     Clouds
# 14                   0.312                     Clouds
# 15                   0.312                     Clouds
# 16                   0.312                     Clouds
# 17                   0.312                     Clouds
# 18                   0.312                     Clouds
# 19                  12.688                       Rain
# 20                   7.750                       Rain
# 21                   1.125                       Rain
# 22                   2.187                       Rain
# 23                   2.187                     Clouds
# 24                   0.188                       Rain
# 25                   0.375                       Rain
# 26                   0.375                     Clouds
# 27                   0.375                     Clouds
# 28                   0.375                      Clear
# 29                  12.812                       Rain
# ..                     ...                        ...
# 250                  1.062                     Clouds
# 251                  1.062                      Clear
# 252                  1.062                     Clouds
# 253                  0.250                       Rain
# 254                  1.688                       Rain
# 255                  1.688                     Clouds
# 256                  1.688                     Clouds
# 257                  1.688                     Clouds
# 258                  1.688                     Clouds
# 259                  1.688                     Clouds
# 260                  1.688                     Clouds
# 261                  0.562                       Rain
# 262                  0.562                     Clouds
# 263                  0.562                     Clouds
# 264                  0.562                     Clouds
# 265                  0.562                     Clouds
# 266                  0.562                     Clouds
# 267                  0.562                     Clouds
# 268                  0.562                     Clouds
# 269                  0.562                     Clouds
# 270                  0.562                     Clouds
# 271                  0.562                     Clouds
# 272                  0.562                     Clouds
# 273                  0.562                     Clouds
# 274                  0.562                     Clouds
# 275                  0.562                      Clear
# 276                  0.562                      Clear
# 277                  0.562                     Clouds
# 278                  0.562                     Clouds
# 279                  0.562                     Clouds
#
#     weather_forecast_detl_desc
# 0                   light rain
# 1                   light rain
# 2                   light rain
# 3              overcast clouds
# 4              overcast clouds
# 5                broken clouds
# 6                broken clouds
# 7                   light rain
# 8                   few clouds
# 9              overcast clouds
# 10             overcast clouds
# 11             overcast clouds
# 12             overcast clouds
# 13             overcast clouds
# 14               broken clouds
# 15             overcast clouds
# 16             overcast clouds
# 17             overcast clouds
# 18             overcast clouds
# 19        heavy intensity rain
# 20               moderate rain
# 21                  light rain
# 22                  light rain
# 23            scattered clouds
# 24                  light rain
# 25                  light rain
# 26               broken clouds
# 27                  few clouds
# 28                   clear sky
# 29        heavy intensity rain
# ..                         ...
# 250              broken clouds
# 251                  clear sky
# 252                 few clouds
# 253                 light rain
# 254                 light rain
# 255              broken clouds
# 256            overcast clouds
# 257            overcast clouds
# 258              broken clouds
# 259            overcast clouds
# 260            overcast clouds
# 261                 light rain
# 262            overcast clouds
# 263            overcast clouds
# 264            overcast clouds
# 265            overcast clouds
# 266            overcast clouds
# 267              broken clouds
# 268              broken clouds
# 269                 few clouds
# 270           scattered clouds
# 271              broken clouds
# 272            overcast clouds
# 273            overcast clouds
# 274              broken clouds
# 275                  clear sky
# 276                  clear sky
# 277              broken clouds
# 278            overcast clouds
# 279            overcast clouds
#
# [280 rows x 15 columns]

# %%
weather_df.to_csv("weather_forecast_data.csv", sep=',', encoding='utf-8')
